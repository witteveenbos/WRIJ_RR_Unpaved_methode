# %% [markdown]
# # 03 Model runnen
#
# Hier worden de gegenereerde modellen gedraaid en de resultaten weggeschreven.
#
# Dit script kan worden gedupliceerd om meerdere modellen parallel te draaien.

# %%
import subprocess
import shutil
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Selecteer de gebieden en scenarios die gedraaid moeten worden
#
# Ook wordt hier de periode waarover de modellen gerdraaid moeten worden aangegeven.

# %%
# selectie_gebied = 0 # Oude IJssel
# selectie_gebied = 1 # West
# selectie_gebied = 2 # Centraal
# selectie_gebied = 3 # Oost
selectie_gebieden = [1,2,3]

scenarios = ["REF"] # , "SCEN"]

# # LONG TEST
# start_date = "2014-07-1"
# end_date = "2016-09-30"
# date_range = pd.date_range(start_date, end_date, freq="3MS")
# seizoenen = ["zomer", "winter", "winter", "zomer"]

# SIMULATIES TBV ONDERZOEK INLOOPTIJD ICM INITIËLE GRONDWATERSTAND

# # run_name, scenario = "OY_5_kD20_L4_W_InfMax_InitGWS_20140101_20160930", "REF"
# start_date = "2014-01-01"
# end_date = "2016-09-30"
# seizoenen = ["winter", "zomer", "zomer", "winter"]
# date_range = pd.date_range(start_date, end_date, freq="3MS")

# # run_name, scenario = "OY_5_kD20_L4_W_InfMax_InitGWS_20130101_20160930", "REF"
# start_date = "2013-01-01"
# end_date = "2016-09-30"
# seizoenen = ["winter", "zomer", "zomer", "winter"]
# date_range = pd.date_range(start_date, end_date, freq="3MS")

# run_name, scenario = "OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930", "REF"
start_date = "2012-04-01"
end_date = "2016-09-30"
seizoenen = ["zomer", "zomer", "winter", "winter"]
date_range = pd.date_range(start_date, end_date, freq="3MS")

# %%
main_dir = Path("D:\\153961_Oude_IJssel")
dir_model_basis = Path(main_dir, "WRIJ_RR_Unpaved_methode_03_modellen")

# run_names = [
#     "OY_0_kD5_L4",
#     "OY_1_kD20_L4",
#     "OY_2_kD20_L2",
#     "OY_3_kD20_L4_W",
#     "OY_4_kD20_L4_W_InfMax",
#     "OY_5_kD20_L4_W_InfMax_InitGWS",
# ]

# # run_name, scenario = "OY_5_kD20_L4_W_InfMax_InitGWS_20140101_20160930", "REF"
# run_names = ["OY_5_kD20_L4_W_InfMax_InitGWS_20140101_20160930"]

# # run_name, scenario = "OY_5_kD20_L4_W_InfMax_InitGWS_20130101_20160930", "REF"
# run_names = ["OY_5_kD20_L4_W_InfMax_InitGWS_20130101_20160930"]

# run_name, scenario = "OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930", "REF"
run_names = ["OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930"]

# %%
simulations_total = pd.DataFrame()

for run_name in run_names:
    for selectie_gebied in selectie_gebieden:
        for scenario in scenarios:
            simulaties = pd.DataFrame()
            
            simulaties["start_date"] = date_range
            simulaties["end_date"] = simulaties["start_date"].shift(-1)
            simulaties.loc[simulaties.index[-1],"end_date"] = pd.to_datetime(end_date)
            simulaties["seizoen"] = (seizoenen * 100)[:len(date_range)]
            simulaties["scenario"] = scenario
            simulaties["gebied"] = selectie_gebied
            simulaties["run_name"] = run_name
            simulaties["restart_in"] = [0] + [1] * len(simulaties.index[1:])
            simulaties["model_name"] = simulaties.apply(lambda x: f"{run_name[:4]}_gebied{selectie_gebied}_{scenario}_rr_{pd.to_datetime(x.start_date).strftime('%Y%m%d')}_{pd.to_datetime(x.end_date).strftime('%Y%m%d')}", axis=1)

            simulations_total = pd.concat([simulations_total, simulaties], axis=0).reset_index(drop=True)

simulations_total
# Out:
#    start_date   end_date seizoen scenario  gebied  \
# 0  2012-04-01 2012-07-01   zomer      REF       1
# 1  2012-07-01 2012-10-01   zomer      REF       1
# 2  2012-10-01 2013-01-01  winter      REF       1
# 3  2013-01-01 2013-04-01  winter      REF       1
# 4  2013-04-01 2013-07-01   zomer      REF       1
# 5  2013-07-01 2013-10-01   zomer      REF       1
# 6  2013-10-01 2014-01-01  winter      REF       1
# 7  2014-01-01 2014-04-01  winter      REF       1
# 8  2014-04-01 2014-07-01   zomer      REF       1
# 9  2014-07-01 2014-10-01   zomer      REF       1
# 10 2014-10-01 2015-01-01  winter      REF       1
# 11 2015-01-01 2015-04-01  winter      REF       1
# 12 2015-04-01 2015-07-01   zomer      REF       1
# 13 2015-07-01 2015-10-01   zomer      REF       1
# 14 2015-10-01 2016-01-01  winter      REF       1
# 15 2016-01-01 2016-04-01  winter      REF       1
# 16 2016-04-01 2016-07-01   zomer      REF       1
# 17 2016-07-01 2016-09-30   zomer      REF       1
# 18 2012-04-01 2012-07-01   zomer      REF       2
# 19 2012-07-01 2012-10-01   zomer      REF       2
# 20 2012-10-01 2013-01-01  winter      REF       2
# 21 2013-01-01 2013-04-01  winter      REF       2
# 22 2013-04-01 2013-07-01   zomer      REF       2
# 23 2013-07-01 2013-10-01   zomer      REF       2
# 24 2013-10-01 2014-01-01  winter      REF       2
# 25 2014-01-01 2014-04-01  winter      REF       2
# 26 2014-04-01 2014-07-01   zomer      REF       2
# 27 2014-07-01 2014-10-01   zomer      REF       2
# 28 2014-10-01 2015-01-01  winter      REF       2
# 29 2015-01-01 2015-04-01  winter      REF       2
# 30 2015-04-01 2015-07-01   zomer      REF       2
# 31 2015-07-01 2015-10-01   zomer      REF       2
# 32 2015-10-01 2016-01-01  winter      REF       2
# 33 2016-01-01 2016-04-01  winter      REF       2
# 34 2016-04-01 2016-07-01   zomer      REF       2
# 35 2016-07-01 2016-09-30   zomer      REF       2
# 36 2012-04-01 2012-07-01   zomer      REF       3
# 37 2012-07-01 2012-10-01   zomer      REF       3
# 38 2012-10-01 2013-01-01  winter      REF       3
# 39 2013-01-01 2013-04-01  winter      REF       3
# 40 2013-04-01 2013-07-01   zomer      REF       3
# 41 2013-07-01 2013-10-01   zomer      REF       3
# 42 2013-10-01 2014-01-01  winter      REF       3
# 43 2014-01-01 2014-04-01  winter      REF       3
# 44 2014-04-01 2014-07-01   zomer      REF       3
# 45 2014-07-01 2014-10-01   zomer      REF       3
# 46 2014-10-01 2015-01-01  winter      REF       3
# 47 2015-01-01 2015-04-01  winter      REF       3
# 48 2015-04-01 2015-07-01   zomer      REF       3
# 49 2015-07-01 2015-10-01   zomer      REF       3
# 50 2015-10-01 2016-01-01  winter      REF       3
# 51 2016-01-01 2016-04-01  winter      REF       3
# 52 2016-04-01 2016-07-01   zomer      REF       3
# 53 2016-07-01 2016-09-30   zomer      REF       3
#
#                                            run_name  restart_in  \
# 0   OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           0
# 1   OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 2   OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 3   OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 4   OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 5   OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 6   OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 7   OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 8   OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 9   OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 10  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 11  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 12  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 13  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 14  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 15  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 16  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 17  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 18  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           0
# 19  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 20  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 21  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 22  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 23  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 24  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 25  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 26  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 27  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 28  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 29  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 30  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 31  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 32  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 33  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 34  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 35  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 36  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           0
# 37  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 38  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 39  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 40  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 41  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 42  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 43  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 44  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 45  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 46  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 47  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 48  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 49  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 50  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 51  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 52  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
# 53  OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930           1
#
#                                model_name
# 0   OY_5_gebied1_REF_rr_20120401_20120701
# 1   OY_5_gebied1_REF_rr_20120701_20121001
# 2   OY_5_gebied1_REF_rr_20121001_20130101
# 3   OY_5_gebied1_REF_rr_20130101_20130401
# 4   OY_5_gebied1_REF_rr_20130401_20130701
# 5   OY_5_gebied1_REF_rr_20130701_20131001
# 6   OY_5_gebied1_REF_rr_20131001_20140101
# 7   OY_5_gebied1_REF_rr_20140101_20140401
# 8   OY_5_gebied1_REF_rr_20140401_20140701
# 9   OY_5_gebied1_REF_rr_20140701_20141001
# 10  OY_5_gebied1_REF_rr_20141001_20150101
# 11  OY_5_gebied1_REF_rr_20150101_20150401
# 12  OY_5_gebied1_REF_rr_20150401_20150701
# 13  OY_5_gebied1_REF_rr_20150701_20151001
# 14  OY_5_gebied1_REF_rr_20151001_20160101
# 15  OY_5_gebied1_REF_rr_20160101_20160401
# 16  OY_5_gebied1_REF_rr_20160401_20160701
# 17  OY_5_gebied1_REF_rr_20160701_20160930
# 18  OY_5_gebied2_REF_rr_20120401_20120701
# 19  OY_5_gebied2_REF_rr_20120701_20121001
# 20  OY_5_gebied2_REF_rr_20121001_20130101
# 21  OY_5_gebied2_REF_rr_20130101_20130401
# 22  OY_5_gebied2_REF_rr_20130401_20130701
# 23  OY_5_gebied2_REF_rr_20130701_20131001
# 24  OY_5_gebied2_REF_rr_20131001_20140101
# 25  OY_5_gebied2_REF_rr_20140101_20140401
# 26  OY_5_gebied2_REF_rr_20140401_20140701
# 27  OY_5_gebied2_REF_rr_20140701_20141001
# 28  OY_5_gebied2_REF_rr_20141001_20150101
# 29  OY_5_gebied2_REF_rr_20150101_20150401
# 30  OY_5_gebied2_REF_rr_20150401_20150701
# 31  OY_5_gebied2_REF_rr_20150701_20151001
# 32  OY_5_gebied2_REF_rr_20151001_20160101
# 33  OY_5_gebied2_REF_rr_20160101_20160401
# 34  OY_5_gebied2_REF_rr_20160401_20160701
# 35  OY_5_gebied2_REF_rr_20160701_20160930
# 36  OY_5_gebied3_REF_rr_20120401_20120701
# 37  OY_5_gebied3_REF_rr_20120701_20121001
# 38  OY_5_gebied3_REF_rr_20121001_20130101
# 39  OY_5_gebied3_REF_rr_20130101_20130401
# 40  OY_5_gebied3_REF_rr_20130401_20130701
# 41  OY_5_gebied3_REF_rr_20130701_20131001
# 42  OY_5_gebied3_REF_rr_20131001_20140101
# 43  OY_5_gebied3_REF_rr_20140101_20140401
# 44  OY_5_gebied3_REF_rr_20140401_20140701
# 45  OY_5_gebied3_REF_rr_20140701_20141001
# 46  OY_5_gebied3_REF_rr_20141001_20150101
# 47  OY_5_gebied3_REF_rr_20150101_20150401
# 48  OY_5_gebied3_REF_rr_20150401_20150701
# 49  OY_5_gebied3_REF_rr_20150701_20151001
# 50  OY_5_gebied3_REF_rr_20151001_20160101
# 51  OY_5_gebied3_REF_rr_20160101_20160401
# 52  OY_5_gebied3_REF_rr_20160401_20160701
# 53  OY_5_gebied3_REF_rr_20160701_20160930

# %% [markdown]
# ### Hier worden de geselecteerde modellen gedraaid
#
# Ook worden restartbestanden doorgegeven, zodat opeenvolgende modelruns op elkaar kunnen aansluiten.

# %%
import time

def calculate_simulation_train(simulations_group):
    simulations_group = simulations_group.reset_index(drop=True)
    for index, simulatie in simulations_group.iterrows():
        print(f"START: {str(simulatie.run_name)} - gebied{str(simulatie.gebied)} - {simulatie.scenario} - {simulatie.model_name} [{index}]")
        dir_model = Path(dir_model_basis, simulatie.run_name, f"gebied_{simulatie.gebied}", simulatie.scenario)

        # copy restart-file from previous run
        if index > 0:
            unpaved_restart_out = Path(dir_model, simulations_group.loc[index-1, "model_name"], "rr", "RSRR_OUT")
            unpaved_restart_in = Path(dir_model, simulations_group.loc[index, "model_name"], "rr", "RSRR_IN")
            shutil.copy(unpaved_restart_out, unpaved_restart_in)

        # print(f"RUN: {str(simulatie.run_name)} - gebied{str(simulatie.gebied)} - {simulatie.scenario} - {simulatie.model_name}")
        workdir = Path(dir_model, simulations_group.loc[index, "model_name"])
        batfile = workdir / "run.bat"
        result = subprocess.run(
            ["cmd.exe", "/c", str(batfile.resolve())],
            cwd=str(workdir),
            capture_output=True,
            text=True
        )

        # print(str(simulatie.gebied) + " - " + simulatie.scenario + " - " + simulatie.model_name)
        # print("STDOUT:")
        # print(result.stdout)
        print(f"FINISH: {str(simulatie.gebied)} - {simulatie.scenario} - {simulatie.model_name}")

# %%
import asyncio
from concurrent.futures import ThreadPoolExecutor

async def main():
    loop = asyncio.get_running_loop()
    with ThreadPoolExecutor() as pool:
        results = await asyncio.gather(
            *(
                loop.run_in_executor(pool, calculate_simulation_train, simulations_group.copy())
                for _, simulations_group in simulations_total.groupby(["run_name", "gebied", "scenario"])
            )
        )
    return results
results = await main()
# Out:
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied1 - REF - OY_5_gebied1_REF_rr_20120401_20120701 [0]START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied2 - REF - OY_5_gebied2_REF_rr_20120401_20120701 [0]
#
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied3 - REF - OY_5_gebied3_REF_rr_20120401_20120701 [0]
# FINISH: 2 - REF - OY_5_gebied2_REF_rr_20120401_20120701
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied2 - REF - OY_5_gebied2_REF_rr_20120701_20121001 [1]
# FINISH: 1 - REF - OY_5_gebied1_REF_rr_20120401_20120701
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied1 - REF - OY_5_gebied1_REF_rr_20120701_20121001 [1]
# FINISH: 2 - REF - OY_5_gebied2_REF_rr_20120701_20121001
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied2 - REF - OY_5_gebied2_REF_rr_20121001_20130101 [2]
# FINISH: 3 - REF - OY_5_gebied3_REF_rr_20120401_20120701
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied3 - REF - OY_5_gebied3_REF_rr_20120701_20121001 [1]
# FINISH: 2 - REF - OY_5_gebied2_REF_rr_20121001_20130101
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied2 - REF - OY_5_gebied2_REF_rr_20130101_20130401 [3]
# FINISH: 1 - REF - OY_5_gebied1_REF_rr_20120701_20121001
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied1 - REF - OY_5_gebied1_REF_rr_20121001_20130101 [2]
# FINISH: 2 - REF - OY_5_gebied2_REF_rr_20130101_20130401
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied2 - REF - OY_5_gebied2_REF_rr_20130401_20130701 [4]
# FINISH: 2 - REF - OY_5_gebied2_REF_rr_20130401_20130701
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied2 - REF - OY_5_gebied2_REF_rr_20130701_20131001 [5]
# FINISH: 1 - REF - OY_5_gebied1_REF_rr_20121001_20130101
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied1 - REF - OY_5_gebied1_REF_rr_20130101_20130401 [3]
# FINISH: 3 - REF - OY_5_gebied3_REF_rr_20120701_20121001
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied3 - REF - OY_5_gebied3_REF_rr_20121001_20130101 [2]
# FINISH: 2 - REF - OY_5_gebied2_REF_rr_20130701_20131001
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied2 - REF - OY_5_gebied2_REF_rr_20131001_20140101 [6]
# FINISH: 1 - REF - OY_5_gebied1_REF_rr_20130101_20130401
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied1 - REF - OY_5_gebied1_REF_rr_20130401_20130701 [4]
# FINISH: 2 - REF - OY_5_gebied2_REF_rr_20131001_20140101
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied2 - REF - OY_5_gebied2_REF_rr_20140101_20140401 [7]
# FINISH: 2 - REF - OY_5_gebied2_REF_rr_20140101_20140401
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied2 - REF - OY_5_gebied2_REF_rr_20140401_20140701 [8]
# FINISH: 3 - REF - OY_5_gebied3_REF_rr_20121001_20130101
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied3 - REF - OY_5_gebied3_REF_rr_20130101_20130401 [3]
# FINISH: 1 - REF - OY_5_gebied1_REF_rr_20130401_20130701
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied1 - REF - OY_5_gebied1_REF_rr_20130701_20131001 [5]
# FINISH: 2 - REF - OY_5_gebied2_REF_rr_20140401_20140701
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied2 - REF - OY_5_gebied2_REF_rr_20140701_20141001 [9]
# FINISH: 2 - REF - OY_5_gebied2_REF_rr_20140701_20141001
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied2 - REF - OY_5_gebied2_REF_rr_20141001_20150101 [10]
# FINISH: 1 - REF - OY_5_gebied1_REF_rr_20130701_20131001
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied1 - REF - OY_5_gebied1_REF_rr_20131001_20140101 [6]
# FINISH: 3 - REF - OY_5_gebied3_REF_rr_20130101_20130401
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied3 - REF - OY_5_gebied3_REF_rr_20130401_20130701 [4]
# FINISH: 2 - REF - OY_5_gebied2_REF_rr_20141001_20150101
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied2 - REF - OY_5_gebied2_REF_rr_20150101_20150401 [11]
# FINISH: 1 - REF - OY_5_gebied1_REF_rr_20131001_20140101
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied1 - REF - OY_5_gebied1_REF_rr_20140101_20140401 [7]
# FINISH: 2 - REF - OY_5_gebied2_REF_rr_20150101_20150401
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied2 - REF - OY_5_gebied2_REF_rr_20150401_20150701 [12]
# FINISH: 2 - REF - OY_5_gebied2_REF_rr_20150401_20150701
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied2 - REF - OY_5_gebied2_REF_rr_20150701_20151001 [13]
# FINISH: 1 - REF - OY_5_gebied1_REF_rr_20140101_20140401
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied1 - REF - OY_5_gebied1_REF_rr_20140401_20140701 [8]
# FINISH: 3 - REF - OY_5_gebied3_REF_rr_20130401_20130701
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied3 - REF - OY_5_gebied3_REF_rr_20130701_20131001 [5]
# FINISH: 2 - REF - OY_5_gebied2_REF_rr_20150701_20151001
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied2 - REF - OY_5_gebied2_REF_rr_20151001_20160101 [14]
# FINISH: 2 - REF - OY_5_gebied2_REF_rr_20151001_20160101
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied2 - REF - OY_5_gebied2_REF_rr_20160101_20160401 [15]
# FINISH: 1 - REF - OY_5_gebied1_REF_rr_20140401_20140701
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied1 - REF - OY_5_gebied1_REF_rr_20140701_20141001 [9]
# FINISH: 2 - REF - OY_5_gebied2_REF_rr_20160101_20160401
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied2 - REF - OY_5_gebied2_REF_rr_20160401_20160701 [16]
# FINISH: 3 - REF - OY_5_gebied3_REF_rr_20130701_20131001
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied3 - REF - OY_5_gebied3_REF_rr_20131001_20140101 [6]
# FINISH: 2 - REF - OY_5_gebied2_REF_rr_20160401_20160701
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied2 - REF - OY_5_gebied2_REF_rr_20160701_20160930 [17]
# FINISH: 1 - REF - OY_5_gebied1_REF_rr_20140701_20141001
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied1 - REF - OY_5_gebied1_REF_rr_20141001_20150101 [10]
# FINISH: 2 - REF - OY_5_gebied2_REF_rr_20160701_20160930
# FINISH: 1 - REF - OY_5_gebied1_REF_rr_20141001_20150101
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied1 - REF - OY_5_gebied1_REF_rr_20150101_20150401 [11]
# FINISH: 3 - REF - OY_5_gebied3_REF_rr_20131001_20140101
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied3 - REF - OY_5_gebied3_REF_rr_20140101_20140401 [7]
# FINISH: 1 - REF - OY_5_gebied1_REF_rr_20150101_20150401
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied1 - REF - OY_5_gebied1_REF_rr_20150401_20150701 [12]
# FINISH: 3 - REF - OY_5_gebied3_REF_rr_20140101_20140401
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied3 - REF - OY_5_gebied3_REF_rr_20140401_20140701 [8]
# FINISH: 1 - REF - OY_5_gebied1_REF_rr_20150401_20150701
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied1 - REF - OY_5_gebied1_REF_rr_20150701_20151001 [13]
# FINISH: 1 - REF - OY_5_gebied1_REF_rr_20150701_20151001
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied1 - REF - OY_5_gebied1_REF_rr_20151001_20160101 [14]
# FINISH: 3 - REF - OY_5_gebied3_REF_rr_20140401_20140701
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied3 - REF - OY_5_gebied3_REF_rr_20140701_20141001 [9]
# FINISH: 1 - REF - OY_5_gebied1_REF_rr_20151001_20160101
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied1 - REF - OY_5_gebied1_REF_rr_20160101_20160401 [15]
# FINISH: 1 - REF - OY_5_gebied1_REF_rr_20160101_20160401
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied1 - REF - OY_5_gebied1_REF_rr_20160401_20160701 [16]
# FINISH: 3 - REF - OY_5_gebied3_REF_rr_20140701_20141001
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied3 - REF - OY_5_gebied3_REF_rr_20141001_20150101 [10]
# FINISH: 1 - REF - OY_5_gebied1_REF_rr_20160401_20160701
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied1 - REF - OY_5_gebied1_REF_rr_20160701_20160930 [17]
# FINISH: 3 - REF - OY_5_gebied3_REF_rr_20141001_20150101
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied3 - REF - OY_5_gebied3_REF_rr_20150101_20150401 [11]
# FINISH: 1 - REF - OY_5_gebied1_REF_rr_20160701_20160930
# FINISH: 3 - REF - OY_5_gebied3_REF_rr_20150101_20150401
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied3 - REF - OY_5_gebied3_REF_rr_20150401_20150701 [12]
# FINISH: 3 - REF - OY_5_gebied3_REF_rr_20150401_20150701
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied3 - REF - OY_5_gebied3_REF_rr_20150701_20151001 [13]
# FINISH: 3 - REF - OY_5_gebied3_REF_rr_20150701_20151001
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied3 - REF - OY_5_gebied3_REF_rr_20151001_20160101 [14]
# FINISH: 3 - REF - OY_5_gebied3_REF_rr_20151001_20160101
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied3 - REF - OY_5_gebied3_REF_rr_20160101_20160401 [15]
# FINISH: 3 - REF - OY_5_gebied3_REF_rr_20160101_20160401
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied3 - REF - OY_5_gebied3_REF_rr_20160401_20160701 [16]
# FINISH: 3 - REF - OY_5_gebied3_REF_rr_20160401_20160701
# START: OY_5_kD20_L4_W_InfMax_InitGWS_20120401_20160930 - gebied3 - REF - OY_5_gebied3_REF_rr_20160701_20160930 [17]
# FINISH: 3 - REF - OY_5_gebied3_REF_rr_20160701_20160930

# %%
# first_simulations = simulations_total.groupby(["gebied", "scenario"]).first()
# last_simulations = simulations_total.groupby(["gebied", "scenario"]).last()

# if use_restart:
#     simulations_total["restart_in"] = 1
#     for selectie_gebied in selectie_gebieden:
#         for scenario in scenarios:
#             last_simulation = last_simulations.loc[(selectie_gebied, scenario)]
#             path_rr_restart_old = Path(
#                 dir_model_restart, 
#                 f"gebied_{selectie_gebied}", 
#                 scenario, 
#                 last_simulation.model_name,
#                 "rr",
#                 "RSRR_OUT"
#             )
#             first_simulation = first_simulations.loc[(selectie_gebied, scenario)]
#             path_rr_restart_new = Path(
#                 dir_model_basis, 
#                 f"gebied_{selectie_gebied}", 
#                 scenario, 
#                 first_simulation.model_name,
#                 "rr",
#                 "RSRR_IN"
#             )
#             path_rr_restart_new.parent.mkdir(parents=True, exist_ok=True)
#             shutil.copy(path_rr_restart_old, path_rr_restart_new)

# simulations_total
